# %%
#!/usr/bin/env python
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from astropy.time import Time
from astroquery.jplhorizons import Horizons

sim_start_date = "2018-01-01"     # simulating a solar system starting from this date
sim_duration = 2 * 365                # (int) simulation duration in days
m_earth = 5.9722e24 / 1.98847e30  # Mass of Earth relative to mass of the sun
m_moon = 7.3477e22 / 1.98847e30

class Object:                   # define the objects: the Sun, Earth, Mercury, etc
    def __init__(self, name, T, a, ecc):
        self.name = name
        self.T = T
        self.a = a
        self.ecc = ecc
        self.xs = []
        self.ys = []
        # self.plot = ax.scatter(r[0], r[1], color=color, s=rad**2, edgecolors=None, zorder=10)
        # self.line, = ax.plot([], [], color=color, linewidth=1.4)

class SolarSystem:
    def __init__(self, thesun):
        self.thesun = thesun
        self.planets = []
        self.time = None
        self.timestamp = ax.text(.03, .94, 'Date: ', color='w', transform=ax.transAxes, fontsize='x-large')
    def add_planet(self, planet):
        self.planets.append(planet)
    def evolve(self):           # evolve the trajectories
        dt = 1.0
        self.time += dt
        plots = []
        lines = []
        for p in self.planets:
            p.r += p.v * dt
            acc = -2.959e-4 * p.r / np.sum(p.r**2)**(3./2)  # in units of AU/day^2
            p.v += acc * dt
            p.xs.append(p.r[0])
            p.ys.append(p.r[1])
            p.plot.set_offsets(p.r[:2])
            p.line.set_xdata(p.xs)
            p.line.set_ydata(p.ys)
            plots.append(p.plot)
            lines.append(p.line)
        self.timestamp.set_text('Date: ' + Time(self.time, format='jd', out_subfmt='date').iso)
        return plots + lines + [self.timestamp]

plt.style.use('dark_background')
fig = plt.figure(figsize=[6, 6])
ax = plt.axes([0., 0., 1., 1.], xlim=(-1.8, 1.8), ylim=(-1.8, 1.8))
ax.set_aspect('equal')
ax.axis('off')
ss = SolarSystem(Object("Sun", 28, 'red', [0, 0, 0], [0, 0, 0]))
ss.time = Time(sim_start_date).jd
colors = ['gray', 'orange', 'blue', 'chocolate']
sizes = [0.38, 0.95, 1., 0.53]
names = ['Mercury', 'Venus', 'Earth', 'Mars']
texty = [.47, .73, 1, 1.5]
for i, nasaid in enumerate([1, 2, 3, 4]):  # The 1st, 2nd, 3rd, 4th planet in solar system
    obj = Horizons(id=nasaid, location="@sun", epochs=ss.time, id_type='id').vectors()
    ss.add_planet(Object(nasaid, 20 * sizes[i], colors[i], 
                         [np.double(obj[xi]) for xi in ['x', 'y', 'z']], 
                         [np.double(obj[vxi]) for vxi in ['vx', 'vy', 'vz']]))
    ax.text(0, - (texty[i] + 0.1), names[i], color=colors[i], zorder=1000, ha='center', fontsize='large')
def animate(i):
    return ss.evolve()
ani = animation.FuncAnimation(fig, animate, repeat=False, frames=sim_duration, blit=True, interval=20,)
plt.show()
# ani.save('solar_system_6in_150dpi.mp4', fps=60, dpi=150)
# Out:
# WARNING: AstropyDeprecationWarning: ``id_type``s 'majorbody' and 'id' are deprecated and replaced with ``None``, which has the same functionality. [astroquery.jplhorizons.core]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\astropy\time\core.py:624, in TimeBase._get_time_fmt(self, val, val2, format, scale, precision, in_subfmt, out_subfmt, mask)
#     623         val, val2 = cls._fill_masked_values(oval, oval2, mask, in_subfmt)
# --> 624     return cls(val, val2, scale, precision, in_subfmt, out_subfmt)
#     625 except UnitConversionError:
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\astropy\time\formats.py:158, in TimeFormat.__init__(self, val1, val2, scale, precision, in_subfmt, out_subfmt, from_jd)
#     157 self.in_subfmt = in_subfmt
# --> 158 self.out_subfmt = out_subfmt
#     160 self._jd1, self._jd2 = None, None
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\astropy\time\formats.py:221, in TimeFormat.out_subfmt(self, subfmt)
#     218 @out_subfmt.setter
#     219 def out_subfmt(self, subfmt):
#     220     # Validate subfmt value for this class, raises ValueError if not.
# --> 221     self._select_subfmts(subfmt)
#     222     self._out_subfmt = subfmt
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\astropy\time\formats.py:453, in TimeFormat._select_subfmts(cls, pattern)
#     452         subfmt_names = [x[0] for x in cls.subfmts]
# --> 453         raise ValueError(
#     454             f"subformat {pattern!r} must match one of "
#     455             f"{subfmt_names} for format {cls.name}"
#     456         )
#     458 return subfmts
#
# ValueError: subformat 'date' must match one of ['float', 'long', 'decimal', 'str', 'bytes'] for format jd
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\sim.ipynb Cell 1 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/gvnin/Documents/berkeley/astro120/astro120-lab4/sim.ipynb#W0sZmlsZQ%3D%3D?line=66'>67</a> def animate(i):
#      <a href='vscode-notebook-cell:/c%3A/Users/gvnin/Documents/berkeley/astro120/astro120-lab4/sim.ipynb#W0sZmlsZQ%3D%3D?line=67'>68</a>     return ss.evolve()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/gvnin/Documents/berkeley/astro120/astro120-lab4/sim.ipynb#W0sZmlsZQ%3D%3D?line=68'>69</a> ani = animation.FuncAnimation(fig, animate, repeat=False, frames=sim_duration, blit=True, interval=20,)
#      <a href='vscode-notebook-cell:/c%3A/Users/gvnin/Documents/berkeley/astro120/astro120-lab4/sim.ipynb#W0sZmlsZQ%3D%3D?line=69'>70</a> plt.show()
#      <a href='vscode-notebook-cell:/c%3A/Users/gvnin/Documents/berkeley/astro120/astro120-lab4/sim.ipynb#W0sZmlsZQ%3D%3D?line=70'>71</a> # ani.save('solar_system_6in_150dpi.mp4', fps=60, dpi=150)
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\matplotlib\animation.py:1695, in FuncAnimation.__init__(self, fig, func, frames, init_func, fargs, save_count, cache_frame_data, **kwargs)
#    1692 # Needs to be initialized so the draw functions work without checking
#    1693 self._save_seq = []
# -> 1695 super().__init__(fig, **kwargs)
#    1697 # Need to reset the saved seq, since right now it will contain data
#    1698 # for a single frame from init, which is not what we want.
#    1699 self._save_seq = []
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\matplotlib\animation.py:1417, in TimedAnimation.__init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1415 if event_source is None:
#    1416     event_source = fig.canvas.new_timer(interval=self._interval)
# -> 1417 super().__init__(fig, event_source=event_source, *args, **kwargs)
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\matplotlib\animation.py:888, in Animation.__init__(self, fig, event_source, blit)
#     885 self._close_id = self._fig.canvas.mpl_connect('close_event',
#     886                                               self._stop)
#     887 if self._blit:
# --> 888     self._setup_blit()
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\matplotlib\animation.py:1211, in Animation._setup_blit(self)
#    1209 self._drawn_artists = []
#    1210 # _post_draw needs to be called first to initialize the renderer
# -> 1211 self._post_draw(None, self._blit)
#    1212 # Then we need to clear the Frame for the initial draw
#    1213 # This is typically handled in _on_resize because QT and Tk
#    1214 # emit a resize event on launch, but the macosx backend does not,
#    1215 # thus we force it here for everyone for consistency
#    1216 self._init_draw()
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\matplotlib\animation.py:1166, in Animation._post_draw(self, framedata, blit)
#    1164     self._blit_draw(self._drawn_artists)
#    1165 else:
# -> 1166     self._fig.canvas.draw_idle()
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\matplotlib\backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\matplotlib\backends\backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\matplotlib\figure.py:3164, in Figure.draw(self, renderer)
#    3161 finally:
#    3162     self.stale = False
# -> 3164 DrawEvent("draw_event", self.canvas, renderer)._process()
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\matplotlib\backend_bases.py:1271, in Event._process(self)
#    1269 def _process(self):
#    1270     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1271     self.canvas.callbacks.process(self.name, self)
#    1272     self._guiEvent_deleted = True
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\matplotlib\cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\matplotlib\cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\matplotlib\cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\matplotlib\animation.py:912, in Animation._start(self, *args)
#     909 self._fig.canvas.mpl_disconnect(self._first_draw_id)
#     911 # Now do any initial draw
# --> 912 self._init_draw()
#     914 # Add our callback for stepping the animation and
#     915 # actually start the event_source.
#     916 self.event_source.add_callback(self._step)
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\matplotlib\animation.py:1749, in FuncAnimation._init_draw(self)
#    1741         warnings.warn(
#    1742             "Can not start iterating the frames for the initial draw. "
#    1743             "This can be caused by passing in a 0 length sequence "
#    (...)
#    1746             "it may be exhausted due to a previous display or save."
#    1747         )
#    1748         return
# -> 1749     self._draw_frame(frame_data)
#    1750 else:
#    1751     self._drawn_artists = self._init_func()
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\matplotlib\animation.py:1768, in FuncAnimation._draw_frame(self, framedata)
#    1764     self._save_seq = self._save_seq[-self._save_count:]
#    1766 # Call the func with framedata and args. If blitting is desired,
#    1767 # func needs to return a sequence of any artists that were modified.
# -> 1768 self._drawn_artists = self._func(framedata, *self._args)
#    1770 if self._blit:
#    1772     err = RuntimeError('The animation function must return a sequence '
#    1773                        'of Artist objects.')
#
# c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\sim.ipynb Cell 1 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/gvnin/Documents/berkeley/astro120/astro120-lab4/sim.ipynb#W0sZmlsZQ%3D%3D?line=66'>67</a> def animate(i):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/gvnin/Documents/berkeley/astro120/astro120-lab4/sim.ipynb#W0sZmlsZQ%3D%3D?line=67'>68</a>     return ss.evolve()
#
# c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\sim.ipynb Cell 1 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/gvnin/Documents/berkeley/astro120/astro120-lab4/sim.ipynb#W0sZmlsZQ%3D%3D?line=44'>45</a>     plots.append(p.plot)
#      <a href='vscode-notebook-cell:/c%3A/Users/gvnin/Documents/berkeley/astro120/astro120-lab4/sim.ipynb#W0sZmlsZQ%3D%3D?line=45'>46</a>     lines.append(p.line)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/gvnin/Documents/berkeley/astro120/astro120-lab4/sim.ipynb#W0sZmlsZQ%3D%3D?line=46'>47</a> self.timestamp.set_text('Date: ' + Time(self.time, format='jd', out_subfmt='date').iso)
#      <a href='vscode-notebook-cell:/c%3A/Users/gvnin/Documents/berkeley/astro120/astro120-lab4/sim.ipynb#W0sZmlsZQ%3D%3D?line=47'>48</a> return plots + lines + [self.timestamp]
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\astropy\time\core.py:1977, in Time.__init__(self, val, val2, format, scale, precision, in_subfmt, out_subfmt, location, copy)
#    1975         self._set_scale(scale)
#    1976 else:
# -> 1977     self._init_from_vals(
#    1978         val, val2, format, scale, copy, precision, in_subfmt, out_subfmt
#    1979     )
#    1980     self.SCALES = TIME_TYPES[self.scale]
#    1982 if self.location is not None and (
#    1983     self.location.size > 1 and self.location.shape != self.shape
#    1984 ):
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\astropy\time\core.py:548, in TimeBase._init_from_vals(self, val, val2, format, scale, copy, precision, in_subfmt, out_subfmt)
#     545 mask, val_data2 = get_mask_and_data(mask, val2)
#     547 # Parse / convert input values into internal jd1, jd2 based on format
# --> 548 self._time = self._get_time_fmt(
#     549     val_data, val_data2, format, scale, precision, in_subfmt, out_subfmt, mask
#     550 )
#     551 self._format = self._time.name
#     553 # Hack from #9969 to allow passing the location value that has been
#     554 # collected by the TimeAstropyTime format class up to the Time level.
#     555 # TODO: find a nicer way.
#
# File c:\Users\gvnin\Documents\berkeley\astro120\astro120-lab4\venv\Lib\site-packages\astropy\time\core.py:632, in TimeBase._get_time_fmt(self, val, val2, format, scale, precision, in_subfmt, out_subfmt, mask)
#     627 except (ValueError, TypeError) as err:
#     628     # If ``format`` specified then there is only one possibility, so raise
#     629     # immediately and include the upstream exception message to make it
#     630     # easier for user to see what is wrong.
#     631     if len(formats) == 1:
# --> 632         raise ValueError(
#     633             f"Input values did not match the format class {format}:"
#     634             + os.linesep
#     635             + f"{err.__class__.__name__}: {err}"
#     636         ) from err
#     637     else:
#     638         problems[name] = err
#
# ValueError: Input values did not match the format class jd:
# ValueError: subformat 'date' must match one of ['float', 'long', 'decimal', 'str', 'bytes'] for format jd
